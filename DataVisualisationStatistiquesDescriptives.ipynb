# %% [markdown]
# **Visualisation d’un nuage de points et exploration des
# variables**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
prix = pd.read_csv('house_pricing.csv');
print(prix)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df = pd.read_csv('house_pricing.csv');
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# object caregoriel sinon quantitative

# %% [markdown]
# Il faut donner le jeu de données "sur l'univers avec tant d'individu avec tant que caractéristique"
#
# un jeu de donnée qui est relatif à
# Des caractéristiques relative à ...
# Et nous avons une caractéristiques qui va fortememnt nous intérésser pour notre exposé et ...
#
# Poser une problèmatique pertinante
# Utiliser est-ce que

# %%
value = a.loc[(a['LotArea'] < 20000) & (a['SalePrice']<500000)]
sns.relplot(x="LotArea",y="SalePrice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 value = a.loc[(a['LotArea'] < 20000) & (a['SalePrice']<500000)]
#       2 sns.relplot(x="LotArea",y="SalePrice")
#
# NameError: name 'a' is not defined

# %%
sns.set_theme()
sns.relplot(x='LotArea', y ='SalePrice', data = df, hue ="LotArea")
sns.relplot(x='LotArea', y ='SalePrice', data = df, hue ="SalePrice")

# %%
df['LotArea']
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
tmp = df[df['LotArea']<20000] ; tmp
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
tmp2 = tmp[tmp['SalePrice']<500000]; tmp2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
sns.set_theme()
sns.relplot(
    x='LotArea',y='SalePrice',
    data = df.query("LotArea<20000 and SalePrice<500000"),
    height=8,
);

# %%
df.query("LotArea<20000 and SalePrice<50000")
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 30    31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 533  534          20       RL         50.0     5000   Pave   NaN      Reg
# 916  917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968  969          50       RM         50.0     5925   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 30          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 495         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 533         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 916         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 968         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.set_theme()
sns.relplot(x='LotFrontage', y ='SalePrice', data = df, hue ="LotFrontage")
sns.relplot(x='LotFrontage', y ='SalePrice', data = df, hue ="SalePrice")

# %%
sns.set_theme()
sns.relplot(
    y='LotArea',x='LotFrontage',
    data = df.query("LotArea<100000 and LotFrontage<200"),
    height=8,
);

# %%
sns.set_theme()
sns.relplot( x='LotArea',y='LotFrontage',data = df);

# %% [markdown]
# **Visualisation de relations continues**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pred = pd.read_csv('sales_predictions.csv'); pred
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %% [markdown]
# Correlation : Mettre un chiffre sur l'intensité de deux variables

# %%
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
pred.dtypes
# Out:
# date               object
# date_block_num      int64
# shop_id             int64
# item_id             int64
# item_price        float64
# item_cnt_day      float64
# dtype: object

# %%
sns.set_theme()
sns.relplot(y='item_price',x='date',data = pred);

# %%
pred = pd.DataFrame(data=pred, columns=['item_price','date']).sample(n=50)

sns.relplot(x=pred["date"], y=pred["item_price"])

# %% [markdown]
# sns.displot(pred,y='item_price',x='date', kind="line")

# %% [markdown]
# **Visualisation de variables catégoriques**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df2 = pd.read_csv('ibhm_hr_attrition.csv');

# %%
df2.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sns.set_theme()
sns.catplot(x='Attrition', y='JobSatisfaction',data = df2);

# %%
sns.catplot(x="JobSatisfaction", y="Attrition", data=df2, kind="box")

# %% [markdown]
# La médiane est le trait vertical
# Il n'y a pas d'abération car il n'y a pas de trait ou de points.

# %%
sns.boxplot(x='Attrition', y='JobSatisfaction',data = df2);

# %% [markdown]
# Non on ne peut pas les voir

# %%
df2.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.JobSatisfaction.describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sns.boxplot(x="JobSatisfaction", data = df2)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction'>

# %%
sns.catplot(x='Attrition', y='TotalWorkingYears',data = df2);

# %%
sns.boxplot(x='Attrition', y='TotalWorkingYears',data = df2);

# %%
sns.catplot(y="Attrition", x="TotalWorkingYears", data=df2, kind="box")

# %% [markdown]
# L'échantillon est réduit car on a réudit les valeurs donc tout les statistiques sont recalculer par rapport à ce qu'on a maintenant

# %%
sns.boxplot(
    x='TotalWorkingYears',y='Attrition',
    data = df2.query("TotalWorkingYears<20"),
);

# %%
df2['Attrition'] = df2['Attrition'].replace({'Yes':1})
df2['Attrition'] = df2['Attrition'].replace({'No':0})
df2.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sns.catplot(x="EducationField", y="Attrition", data= df2, kind="bar", height=10)

# %% [markdown]
# Le taux d'attrition moyen ne peut pas être signification pour le moment car il faudrait avoir + de détail

# %%
sns.distplot()
