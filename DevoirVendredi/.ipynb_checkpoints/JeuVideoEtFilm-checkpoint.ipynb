# %% [markdown]
# **Jeu vidéo adapté en film**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
videogamefilm = pd.read_csv('video_game_films.csv');
videogame = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv');

# %%
videogamefilm
# Out:
#                                             Title Release date  \
# 0                               Super Mario Bros.   1993-05-28
# 1                                   Double Dragon   1994-11-04
# 2                                  Street Fighter   1994-12-23
# 3                                   Mortal Kombat   1995-08-18
# 4                     Mortal Kombat: Annihilation   1997-11-21
# 5                                  Wing Commander   1999-03-12
# 6                         Lara Croft: Tomb Raider   2001-06-15
# 7                                   Resident Evil   2002-03-15
# 8    Lara Croft: Tomb Raider – The Cradle of Life   2003-07-25
# 9                               House of the Dead   2003-10-10
# 10                      Resident Evil: Apocalypse   2004-09-10
# 11                              Alone in the Dark   2005-01-28
# 12                                           Doom   2005-10-21
# 13                                     BloodRayne   2006-01-06
# ...

# %%
videogame.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# final_df = pd.merge(videogame, videogamefilm, on='Title')

# %% [markdown]
# final = pd.concat([videogame,videogamefilm])

# %% [markdown]
# rslt_df = final[final['Title'] == 'Super Mario Bros.']
# rslt_df.head()

# %%
videogamefilmM = pd.read_csv('video_game_films_modifie.csv');
videogameM = pd.read_csv('Video_Games_Sales_modifie.csv');

# %%
videogamefilmM.head()
# Out:
#                Title Release date  Worldwide box office  Rotten Tomatoes  \
# 0  Alone in the Dark   2005-01-28            10442808.0              1.0
# 1   Assassin's Creed   2016-12-21           240558621.0             18.0
# 2         BloodRayne   2006-01-06             3650275.0              4.0
# 3       Dead Trigger   2019-05-03              151493.0              NaN
# 4  Detective Pikachu   2019-05-10           433005346.0             68.0
#
#    Metacritic            Distributor      Original game publisher  \
# 0         9.0        Lionsgate Films                   Infogrames
# 1        36.0       20th Century Fox                      Ubisoft
# 2        18.0    Boll KG Productions        Majesco Entertainment
# 3         NaN            Saban Films              Madfinger Games
# 4        53.0  Warner Bros. Pictures  NintendoThe Pokémon Company
#
#               Surnom
# 0  Alone in the Dark
# 1   Assassin's Creed
# 2         BloodRayne
# 3                NaN
# ...

# %%
videogameM.head()
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                               1942      NES           1985.0       Shooter
# 1       ¡Shin Chan Flipa en colores!       DS           2007.0      Platform
# 2  .hack: Sekai no Mukou ni + Versus      PS3           2012.0        Action
# 3         .hack//G.U. Vol.1//Rebirth      PS2           2006.0  Role-Playing
# 4       .hack//G.U. Vol.2//Reminisce      PS2           2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0              Capcom      0.65      0.14      0.21         0.00
# 1           505 Games      0.00      0.00      0.14         0.00
# 2  Namco Bandai Games      0.00      0.00      0.03         0.00
# 3  Namco Bandai Games      0.00      0.00      0.17         0.00
# 4  Namco Bandai Games      0.11      0.09      0.00         0.03
#
#    Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Developer  \
# ...

# %%
melange = pd.merge(videogameM, videogamefilmM, on='Surnom')
#dropna va permettre de retirer les valeurs NaN tandis que reset_index va remettre l index à zero
melangeF = melange.dropna(subset=['Surnom'])
melangeF = melangeF.reset_index(drop=True)

melangeF
# Out:
#                                          Name Platform  Year_of_Release  \
# 0                           Alone in the Dark     X360           2008.0
# 1                           Alone in the Dark      Wii           2008.0
# 2                           Alone in the Dark      PS2           2008.0
# 3                           Alone in the Dark       PC           2008.0
# 4                  Alone in the Dark: Inferno      PS3           2008.0
# ...                                       ...      ...              ...
# 1167          Warcraft III: The Frozen Throne       PC           2003.0
# 1168                  Warcraft: Orcs & Humans       PC           1994.0
# 1169   Wing Commander III: Heart of the Tiger       PS           1996.0
# 1170  Wing Commander IV: The Price of Freedom       PS           1997.0
# 1171                 Wing Commander: Prophecy      GBA           2003.0
#
#            Genre                  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
