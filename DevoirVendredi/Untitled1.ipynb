# %% [markdown]
# **Jeu vidéo adapté en film**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re

# %%
videogamefilm = pd.read_csv('video_game_films.csv');
videogame = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv');

# %%
videogamefilm.head()
# Out:
#                          Title Release date  Worldwide box office  \
# 0            Super Mario Bros.   1993-05-28            38912465.0
# 1                Double Dragon   1994-11-04             4152699.0
# 2               Street Fighter   1994-12-23            99423521.0
# 3                Mortal Kombat   1995-08-18           124741822.0
# 4  Mortal Kombat: Annihilation   1997-11-21            51376861.0
#
#    Rotten Tomatoes  Metacritic                        Distributor  \
# 0             24.0        35.0  Buena Vista Pictures Distribution
# 1             13.0         NaN                  Gramercy Pictures
# 2             13.0        34.0                 Universal Pictures
# 3             44.0        60.0                    New Line Cinema
# 4              2.0        11.0                    New Line Cinema
#
#   Original game publisher
# 0                Nintendo
# 1           Technōs Japan
# 2                  Capcom
# 3                  Midway
# 4                  Midway

# %%
videogame.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
videogame.rename(columns = {'Name': 'Title'}, inplace = True)

# %%
final = pd.concat([videogame,videogamefilm])

# %%
final.head()
# Out:
#                       Title Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  User_Score  \
# 0     41.36     28.96      3.77         8.45         82.53  ...         8.0
# 1     29.08      3.58      6.81         0.77         40.24  ...         NaN
# 2     15.68     12.76      3.79         3.29         35.52  ...         8.3
# 3     15.61     10.93      3.28         2.95         32.77  ...         8.0
# 4     11.27      8.89     10.22         1.00         31.37  ...         NaN
#
#    User_Count  Developer  Rating Release date Worldwide box office  \
# 0       322.0   Nintendo       E          NaN                  NaN
# 1         NaN        NaN     NaN          NaN                  NaN
# 2       709.0   Nintendo       E          NaN                  NaN
# 3       192.0   Nintendo       E          NaN                  NaN
# 4         NaN        NaN     NaN          NaN                  NaN
#
#   Rotten Tomatoes  Metacritic  Distributor  Original game publisher
# 0             NaN         NaN          NaN                      NaN
# 1             NaN         NaN          NaN                      NaN
# 2             NaN         NaN          NaN                      NaN
# 3             NaN         NaN          NaN                      NaN
# 4             NaN         NaN          NaN                      NaN
#
# [5 rows x 22 columns]

# %%
rslt_df = final[final['Title'] == 'Super Mario Bros.']
rslt_df.head()
# Out:
#                  Title Platform  Year_of_Release     Genre Publisher  \
# 1    Super Mario Bros.      NES           1985.0  Platform  Nintendo
# 201  Super Mario Bros.       GB           1999.0  Platform  Nintendo
# 0    Super Mario Bros.      NaN              NaN       NaN       NaN
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  User_Score  \
# 1       29.08      3.58      6.81         0.77         40.24  ...         NaN
# 201      3.40      1.30      0.15         0.22          5.07  ...         NaN
# 0         NaN       NaN       NaN          NaN           NaN  ...         NaN
#
#      User_Count  Developer  Rating Release date Worldwide box office  \
# 1           NaN        NaN     NaN          NaN                  NaN
# 201         NaN        NaN     NaN          NaN                  NaN
# 0           NaN        NaN     NaN   1993-05-28           38912465.0
#
#     Rotten Tomatoes  Metacritic                        Distributor  \
# 1               NaN         NaN                                NaN
# 201             NaN         NaN                                NaN
# 0              24.0        35.0  Buena Vista Pictures Distribution
#
#      Original game publisher
# 1                        NaN
# 201                      NaN
# 0                   Nintendo
#
# [3 rows x 22 columns]

# %%
fin = final.query('Title.str.contains("Mario")', engine='python') 
fin.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4114, in DataFrame.query(self, expr, inplace, **kwargs)
#    4113 try:
# -> 4114     result = self.loc[res]
#    4115 except ValueError:
#    4116     # when res is multi-dimensional loc raises, but this is sometimes a
#    4117     # valid query
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1181, in _LocIndexer._getitem_axis(self, key, axis)
#    1180     return self._get_slice_axis(key, axis=axis)
# -> 1181 elif com.is_bool_indexer(key):
#    1182     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     141 if lib.infer_dtype(key) == "boolean" and isna(key).any():
#     142     # Don't raise on e.g. ["A", "B", np.nan], see
#     143     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144     raise ValueError(na_msg)
#     145 return False
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 fin = final.query('Title.str.contains("Mario")', engine='python')
#       2 fin.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4118, in DataFrame.query(self, expr, inplace, **kwargs)
#    4114     result = self.loc[res]
#    4115 except ValueError:
#    4116     # when res is multi-dimensional loc raises, but this is sometimes a
#    4117     # valid query
# -> 4118     result = self[res]
#    4120 if inplace:
#    4121     self._update_inplace(result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     140     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     141     if lib.infer_dtype(key) == "boolean" and isna(key).any():
#     142         # Don't raise on e.g. ["A", "B", np.nan], see
#     143         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144         raise ValueError(na_msg)
#     145     return False
#     146 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values
